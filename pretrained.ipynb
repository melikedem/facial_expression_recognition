# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
# !pip install facenet_pytorch
from facenet_pytorch import InceptionResnetV1
from torch.autograd import Variable
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# Requirement already satisfied: facenet_pytorch in /usr/local/lib/python3.6/dist-packages (2.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from facenet_pytorch) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from facenet_pytorch) (1.17.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (1.24.3)
# PyTorch Version:  1.3.1
# Torchvision Version:  0.4.2

# %%
from google.colab import drive
drive.mount('/content/gdrive')

training_dir = "/content/gdrive/My Drive/images_fer2013/Training"
testing_dir = "/content/gdrive/My Drive/images_fer2013/PublicTest"
validation_dir = "/content/gdrive/My Drive/images_fer2013/PrivateTest"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
model1 = InceptionResnetV1(pretrained='vggface2').eval()
device = torch.device("cuda" if torch.cuda.is_available()  else "cpu")
model1.to(device)
num_classes = 7

# %%
for param in model1.parameters(): 
    param.requires_grad = False

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Sequential(
            #nn.Linear(512, 1024),
            #nn.ReLU(inplace=True),
            
            #nn.Linear(1024, 512),
            #nn.ReLU(inplace=True),
            
            nn.Linear(512, 256),
            nn.BatchNorm1d(num_features=256),
            nn.ReLU(inplace=True),
            #nn.Linear(256, 128),
            #nn.BatchNorm1d(num_features=128),
            #nn.ReLU(inplace=True),

            nn.Linear(256, num_classes))
        self.dropout = nn.Dropout()
  
    def forward(self, x):
        x = self.fc1(x)
        return x

# %%
net = Model().cuda()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), weight_decay=0.003, lr=0.009, amsgrad=True)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.8)
train_number_epochs = 100

# %%
transforms = transforms.Compose([transforms.Resize(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
                                       ])
train_data = datasets.ImageFolder(training_dir,       
                    transform=transforms)
train_loader = torch.utils.data.DataLoader(train_data,
                   shuffle=True, batch_size=224)
validation_data = datasets.ImageFolder(validation_dir,       
                    transform=transforms)
validation_loader = torch.utils.data.DataLoader(validation_data,
                   shuffle=True, batch_size=64)
test_data = datasets.ImageFolder(testing_dir,       
                    transform=transforms)
test_loader = torch.utils.data.DataLoader(test_data,
                   shuffle=True, batch_size=64)
print(train_loader.dataset.classes)
# Out:
# ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# %%
train_counter = []
train_loss_history = []
train_iteration_number= 0
train_accuracy_history=[]

valid_counter = []
valid_loss_history = []
valid_iteration_number= 0
valid_accuracy_history = []

valid_loss_min = np.Inf

# %%
#optimizer = optim.Adam(net.parameters(), lr=0.0003)
for epoch in range(0,train_number_epochs):
    
    train_class_correct = list(0 for i in range(num_classes))
    train_class_total = list(0 for i in range(num_classes))

    valid_class_correct = list(0 for i in range(num_classes))
    valid_class_total = list(0 for i in range(num_classes))
    running_val_accuracy = 0.0
    running_train_accuracy = 0.0
    running_loss = 0.0
    running_valid_loss = 0.0
    net.train()
    for i, data in enumerate(train_loader,0):
        
        img1 , label = data
        #img1, label = Variable(img1), Variable(label)
        img1 , label = img1.cuda(), label.cuda()
        #img1, label = Variable(img1), Variable(label)
        #row, img0, img1 , label = row.cuda(), img0.cuda(), img1.cuda() , label.cuda()
  
        optimizer.zero_grad()
        output1= model1(img1)      
        output = net(output1)
        _, pred= torch.max(output,1)
        
        #plt.imshow(img1.data[0])
        
        
        
        #a = plt.imshow(img1.data[0].permute(1, 2, 0))
        #plt.title(train_loader.dataset.classes[pred[0]])
        #a.set_title = train_loader.dataset.classes[pred[0]]
        #plt.show()

        loss = criterion(output,label)
        loss.backward()
        optimizer.step()
        #scheduler.step()
        #print("----------------pred")
        #print(pred)
        #print("----------------label")
        #print(label)
        correct = pred.eq(label.view_as(pred))
        for j in range(len(label)):
                        target = label[j].data
                        train_class_correct[target] += correct[j].item()
                        train_class_total[target] += 1

        running_loss += (loss.item() * img1.size(0))
        train_accuracy = 100. * np.sum(train_class_correct) / np.sum(train_class_total)
        running_train_accuracy += (train_accuracy * img1.size(0))
        
        
        if i%40 == 0:
            print("Epoch number {}\n Current loss {}\n".format(epoch+1,loss.item()))
            
            

            for i in range(num_classes):
                if train_class_total[i] > 0:
                        print('\nTraining Accuracy of %5s: %2d%% (%2d/%2d)' % (
                            str(i), 100 * train_class_correct[i] / train_class_total[i],
                            np.sum(train_class_correct[i]), np.sum(train_class_total[i])))

            print('\nTraining Accuracy (Overall): %2d%% (%2d/%2d)' % (
                100. * np.sum(train_class_correct) / np.sum(train_class_total),
                np.sum(train_class_correct), np.sum(train_class_total)))

    scheduler.step()
    train_loss_history.append(running_loss / len(train_data))
    train_iteration_number +=1
    train_counter.append(train_iteration_number)
    train_accuracy_history.append(running_train_accuracy / len(train_data))
    net.eval()
    for i, data in enumerate(test_loader,0):
     
        img1 , label = data
        img1 , label = img1.cuda(), label.cuda()
        
        output1= model1(img1)
        output = net(output1)
        _, pred= output.max(1)
        
        
        loss = criterion(output,label)
        
        correct = pred.eq(label.view_as(pred))
        for j in range(len(label)):
                        target = label[j].data
                        valid_class_correct[target] += correct[j].item()
                        valid_class_total[target] += 1
        
        running_valid_loss += (loss.item() * img1.size(0))
        val_accuracy = 100. * np.sum(valid_class_correct) / np.sum(valid_class_total)
        running_val_accuracy += (val_accuracy * img1.size(0))               
        if i%50 == 0:
            print("Epoch number {}\n Current loss {}\n".format(epoch+1,loss.item()))



        
            for i in range(num_classes):
                if train_class_total[i] > 0:
                        if valid_class_total[i] == 0:
                            valid_class_total[i] = valid_class_total[i]+0.000001
                        print('\nValidation Accuracy of %5s: %2d%% (%2d/%2d)' % (
                            str(i), 100 * valid_class_correct[i] / (valid_class_total[i]),
                            np.sum(valid_class_correct[i]), np.sum(valid_class_total[i])))

            print('\nValidation Accuracy (Overall): %2d%% (%2d/%2d)' % (
                100. * np.sum(valid_class_correct) / np.sum(valid_class_total),
                np.sum(valid_class_correct), np.sum(valid_class_total)))
            
    
    valid_loss_history.append(running_valid_loss / len(test_data))
    valid_iteration_number +=1
    valid_counter.append(valid_iteration_number)
    val = running_valid_loss / len(test_data) 
    print("Validation loss for epoch {}: {:.6f}".format(epoch+1,val))
    valid_accuracy_history.append(running_val_accuracy / len(test_data))
    if val <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        val))
        torch.save(net, "/content/gdrive/My Drive/pretrained.pth")
        valid_loss_min = val
# Out:
# Epoch number 1
#  Current loss 1.6358754634857178
#
#
# Training Accuracy of     0: 26% ( 7/26)
#
# Training Accuracy of     1:  0% ( 0/ 5)
#
# Training Accuracy of     2:  2% ( 1/35)
#
# Training Accuracy of     3: 87% (42/48)
#
# Training Accuracy of     4: 43% (17/39)
#
# Training Accuracy of     5: 28% (10/35)
#
# Training Accuracy of     6: 22% ( 8/36)
#
# Training Accuracy (Overall): 37% (85/224)
# Epoch number 1
#  Current loss 1.6674537658691406
#
#
# Training Accuracy of     0: 16% (204/1253)
#
# Training Accuracy of     1:  0% ( 0/140)
#
# Training Accuracy of     2:  8% (114/1336)
#
# Training Accuracy of     3: 74% (1744/2337)
#
# Training Accuracy of     4: 28% (457/1587)
#
# Training Accuracy of     5: 32% (496/1525)
#
# Training Accuracy of     6: 18% (191/1006)
#
# Training Accuracy (Overall): 34% (3206/9184)
# Epoch number 1
#  Current loss 1.6075643301010132
#
#
# Training Accuracy of     0: 18% (475/2550)
#
# Training Accuracy of     1:  0% ( 0/267)
#
# Training Accuracy of     2:  7% (185/2611)
#
# Training Accuracy of     3: 73% (3344/4554)
#
# Training Accuracy of     4: 29% (928/3110)
#
# Training Accuracy of     5: 32% (997/3044)
#
# Training Accuracy of     6: 19% (386/2008)
#
# Training Accuracy (Overall): 34% (6315/18144)
# Epoch number 1
#  Current loss 1.6467176675796509
#
#
# Training Accuracy of     0: 17% (672/3776)
#
# Training Accuracy of     1:  0% ( 0/403)
#
# Training Accuracy of     2:  5% (226/3856)
#
# Training Accuracy of     3: 73% (5046/6839)
#
# Training Accuracy of     4: 29% (1405/4690)
#
# Training Accuracy of     5: 34% (1579/4564)
#
# Training Accuracy of     6: 18% (555/2976)
#
# Training Accuracy (Overall): 34% (9483/27104)
# Epoch number 1
#  Current loss 1.6954598426818848
#
#
# Validation Accuracy of     0:  0% ( 0/ 5)
#
# Validation Accuracy of     1:  0% ( 0/ 1)
#
# Validation Accuracy of     2:  0% ( 0/ 9)
#
# Validation Accuracy of     3: 61% ( 8/13)
#
# Validation Accuracy of     4: 20% ( 3/15)
#
# Validation Accuracy of     5: 35% ( 5/14)
#
# Validation Accuracy of     6: 42% ( 3/ 7)
#
# Validation Accuracy (Overall): 29% (19/64)
# Epoch number 1
#  Current loss 1.7769299745559692
#
#
# Validation Accuracy of     0: 13% (57/421)
#
# Validation Accuracy of     1:  0% ( 0/51)
#
# Validation Accuracy of     2:  5% (27/451)
#
# Validation Accuracy of     3: 70% (577/818)
#
# Validation Accuracy of     4: 29% (162/542)
#
# Validation Accuracy of     5: 30% (186/605)
#
# Validation Accuracy of     6: 25% (94/376)
#
# Validation Accuracy (Overall): 33% (1103/3264)
# Validation loss for epoch 1: 1.668103
# Validation loss decreased (1.669656 --> 1.668103).  Saving model ...
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Model. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch number 2
#  Current loss 1.6304913759231567
#
#
# Training Accuracy of     0: 12% ( 3/24)
#
# Training Accuracy of     1:  0% ( 0/ 2)
#
# Training Accuracy of     2:  3% ( 1/32)
#
# Training Accuracy of     3: 71% (42/59)
#
# Training Accuracy of     4: 25% (12/47)
#
# Training Accuracy of     5: 41% (14/34)
#
# Training Accuracy of     6: 15% ( 4/26)
#
# Training Accuracy (Overall): 33% (76/224)
# Epoch number 2
#  Current loss 1.6563359498977661
#
#
# Training Accuracy of     0: 17% (220/1263)
#
# Training Accuracy of     1:  0% ( 0/144)
#
# Training Accuracy of     2:  6% (84/1368)
#
# Training Accuracy of     3: 71% (1603/2252)
#
# Training Accuracy of     4: 32% (525/1601)
#
# Training Accuracy of     5: 37% (598/1590)
#
# Training Accuracy of     6: 16% (155/966)
#
# Training Accuracy (Overall): 34% (3185/9184)
# Epoch number 2
#  Current loss 1.659454584121704
#
#
# Training Accuracy of     0: 17% (427/2494)
#
# Training Accuracy of     1:  0% ( 0/293)
#
# Training Accuracy of     2:  6% (167/2667)
#
# Training Accuracy of     3: 74% (3393/4562)
#
# Training Accuracy of     4: 32% (1011/3116)
#
# Training Accuracy of     5: 32% (1001/3038)
#
# Training Accuracy of     6: 17% (354/1974)
#
# Training Accuracy (Overall): 35% (6353/18144)
# Epoch number 2
#  Current loss 1.6042221784591675
#
#
# Training Accuracy of     0: 18% (686/3786)
#
# Training Accuracy of     1:  0% ( 0/419)
#
# Training Accuracy of     2:  4% (186/3870)
#
# Training Accuracy of     3: 74% (5051/6812)
#
# Training Accuracy of     4: 31% (1486/4659)
#
# Training Accuracy of     5: 34% (1576/4550)
#
# Training Accuracy of     6: 19% (597/3008)
#
# Training Accuracy (Overall): 35% (9582/27104)
# Epoch number 2
#  Current loss 1.6584244966506958
#
#
# Validation Accuracy of     0:  0% ( 0/ 8)
#
# Validation Accuracy of     1:  0% ( 0/ 0)
#
# Validation Accuracy of     2:  0% ( 0/ 6)
#
# Validation Accuracy of     3: 66% (12/18)
#
# Validation Accuracy of     4: 25% ( 2/ 8)
#
# Validation Accuracy of     5: 28% ( 4/14)
#
# Validation Accuracy of     6: 20% ( 2/10)
#
# Validation Accuracy (Overall): 31% (20/64)
# Epoch number 2
#  Current loss 1.6441853046417236
#
#
# Validation Accuracy of     0:  9% (39/428)
#
# Validation Accuracy of     1:  0% ( 0/50)
#
# Validation Accuracy of     2:  4% (21/451)
#
# Validation Accuracy of     3: 70% (577/814)
#
# Validation Accuracy of     4: 32% (180/552)
#
# Validation Accuracy of     5: 36% (217/594)
#
# Validation Accuracy of     6: 21% (81/375)
#
# Validation Accuracy (Overall): 34% (1115/3264)
# Validation loss for epoch 2: 1.668943
# Epoch number 3
#  Current loss 1.622727394104004
#
#
# Training Accuracy of     0:  3% ( 1/30)
#
# Training Accuracy of     1:  0% ( 0/ 1)
#
# Training Accuracy of     2:  2% ( 1/34)
#
# Training Accuracy of     3: 80% (48/60)
#
# Training Accuracy of     4: 40% (18/45)
#
# Training Accuracy of     5: 32% (11/34)
#
# Training Accuracy of     6: 30% ( 6/20)
#
# Training Accuracy (Overall): 37% (85/224)
# Epoch number 3
#  Current loss 1.69171941280365
#
#
# Training Accuracy of     0: 11% (144/1227)
#
# Training Accuracy of     1:  0% ( 0/136)
#
# Training Accuracy of     2:  4% (56/1315)
#
# Training Accuracy of     3: 74% (1735/2327)
#
# Training Accuracy of     4: 34% (551/1619)
#
# Training Accuracy of     5: 33% (516/1527)
#
# Training Accuracy of     6: 18% (193/1033)
#
# Training Accuracy (Overall): 34% (3195/9184)
# Epoch number 3
#  Current loss 1.6438496112823486
#
#
# Training Accuracy of     0: 12% (323/2490)
#
# Training Accuracy of     1:  0% ( 0/276)
#
# Training Accuracy of     2:  4% (125/2576)
#
# Training Accuracy of     3: 73% (3383/4574)
#
# Training Accuracy of     4: 31% (996/3128)
#
# Training Accuracy of     5: 38% (1187/3096)
#
# Training Accuracy of     6: 18% (375/2004)
#
# Training Accuracy (Overall): 35% (6389/18144)
# Epoch number 3
#  Current loss 1.6807032823562622
#
#
# Training Accuracy of     0: 16% (624/3780)
#
# Training Accuracy of     1:  0% ( 0/412)
#
# Training Accuracy of     2:  4% (193/3865)
#
# Training Accuracy of     3: 73% (4989/6792)
#
# Training Accuracy of     4: 32% (1524/4700)
#
# Training Accuracy of     5: 35% (1604/4577)
#
# Training Accuracy of     6: 18% (546/2978)
#
# Training Accuracy (Overall): 34% (9480/27104)
# Epoch number 3
#  Current loss 1.5534939765930176
#
#
# Validation Accuracy of     0: 12% ( 1/ 8)
#
# Validation Accuracy of     1:  0% ( 0/ 1)
#
# Validation Accuracy of     2: 11% ( 1/ 9)
#
# Validation Accuracy of     3: 85% (17/20)
#
# Validation Accuracy of     4: 33% ( 3/ 9)
#
# Validation Accuracy of     5: 36% ( 4/11)
#
# Validation Accuracy of     6:  0% ( 0/ 6)
#
# Validation Accuracy (Overall): 40% (26/64)
# Epoch number 3
#  Current loss 1.559499979019165
#
#
# Validation Accuracy of     0: 15% (67/422)
#
# Validation Accuracy of     1:  0% ( 0/49)
#
# Validation Accuracy of     2:  5% (26/463)
#
# Validation Accuracy of     3: 75% (613/813)
#
# Validation Accuracy of     4: 24% (137/549)
#
# Validation Accuracy of     5: 29% (174/597)
#
# Validation Accuracy of     6: 26% (100/371)
#
# Validation Accuracy (Overall): 34% (1117/3264)
# Validation loss for epoch 3: 1.666113
# Validation loss decreased (1.668103 --> 1.666113).  Saving model ...
# Epoch number 4
#  Current loss 1.6785684823989868
#
#
# Training Accuracy of     0: 20% ( 6/29)
#
# Training Accuracy of     1:  0% ( 0/ 4)
#
# Training Accuracy of     2:  3% ( 1/32)
#
# Training Accuracy of     3: 88% (44/50)
#
# Training Accuracy of     4: 17% ( 7/39)
#
# Training Accuracy of     5: 36% (17/46)
#
# Training Accuracy of     6:  8% ( 2/24)
#
# Training Accuracy (Overall): 34% (77/224)
# Epoch number 4
#  Current loss 1.6510136127471924
#
#
# Training Accuracy of     0: 17% (218/1268)
#
# Training Accuracy of     1:  0% ( 0/129)
#
# Training Accuracy of     2:  6% (84/1295)
#
# Training Accuracy of     3: 77% (1829/2374)
#
# Training Accuracy of     4: 28% (457/1586)
#
# Training Accuracy of     5: 31% (490/1542)
#
# Training Accuracy of     6: 17% (171/990)
#
# Training Accuracy (Overall): 35% (3249/9184)
# Epoch number 4
#  Current loss 1.6734470129013062
#
#
# Training Accuracy of     0: 17% (425/2499)
#
# Training Accuracy of     1:  0% ( 0/270)
#
# Training Accuracy of     2:  6% (178/2623)
#
# Training Accuracy of     3: 75% (3434/4565)
#
# Training Accuracy of     4: 30% (950/3161)
#
# Training Accuracy of     5: 33% (1006/3031)
#
# Training Accuracy of     6: 21% (427/1995)
#
# Training Accuracy (Overall): 35% (6420/18144)
# Epoch number 4
#  Current loss 1.6702907085418701
#
#
# Training Accuracy of     0: 17% (654/3774)
#
# Training Accuracy of     1:  0% ( 0/403)
#
# Training Accuracy of     2:  5% (219/3858)
#
# Training Accuracy of     3: 74% (5117/6829)
#
# Training Accuracy of     4: 30% (1451/4702)
#
# Training Accuracy of     5: 34% (1563/4547)
#
# Training Accuracy of     6: 20% (605/2991)
#
# Training Accuracy (Overall): 35% (9609/27104)
# Epoch number 4
#  Current loss 1.7404085397720337
#
#
# Validation Accuracy of     0:  0% ( 0/ 8)
#
# Validation Accuracy of     1:  0% ( 0/ 2)
#
# Validation Accuracy of     2:  0% ( 0/10)
#
# Validation Accuracy of     3: 64% (11/17)
#
# Validation Accuracy of     4: 50% ( 5/10)
#
# Validation Accuracy of     5: 36% ( 4/11)
#
# Validation Accuracy of     6: 33% ( 2/ 6)
#
# Validation Accuracy (Overall): 34% (22/64)
# Epoch number 4
#  Current loss 1.6568214893341064
#
#
# Validation Accuracy of     0: 18% (79/423)
#
# Validation Accuracy of     1:  0% ( 0/54)
#
# Validation Accuracy of     2:  3% (15/449)
#
# Validation Accuracy of     3: 67% (551/820)
#
# Validation Accuracy of     4: 31% (174/544)
#
# Validation Accuracy of     5: 37% (225/594)
#
# Validation Accuracy of     6: 16% (62/380)
#
# Validation Accuracy (Overall): 33% (1106/3264)
# Validation loss for epoch 4: 1.670876
# Epoch number 5
#  Current loss 1.6601115465164185
#
#
# Training Accuracy of     0: 25% ( 8/32)
#
# Training Accuracy of     1:  0% ( 0/ 3)
#
# Training Accuracy of     2:  8% ( 3/34)
#
# Training Accuracy of     3: 73% (42/57)
#
# Training Accuracy of     4: 15% ( 6/38)
#
# Training Accuracy of     5: 37% (15/40)
#
# Training Accuracy of     6:  5% ( 1/20)
#
# Training Accuracy (Overall): 33% (75/224)
# Epoch number 5
#  Current loss 1.6518741846084595
#
#
# Training Accuracy of     0: 17% (214/1246)
#
# Training Accuracy of     1:  0% ( 0/129)
#
# Training Accuracy of     2:  5% (74/1331)
#
# Training Accuracy of     3: 72% (1652/2289)
#
# Training Accuracy of     4: 33% (529/1602)
#
# Training Accuracy of     5: 36% (585/1582)
#
# Training Accuracy of     6: 14% (150/1005)
#
# Training Accuracy (Overall): 34% (3204/9184)
# Epoch number 5
#  Current loss 1.620768427848816
#
#
# Training Accuracy of     0: 19% (487/2536)
#
# Training Accuracy of     1:  0% ( 0/270)
#
# Training Accuracy of     2:  4% (116/2609)
#
# Training Accuracy of     3: 72% (3284/4533)
#
# Training Accuracy of     4: 32% (1040/3177)
#
# Training Accuracy of     5: 35% (1085/3024)
#
# Training Accuracy of     6: 18% (365/1995)
#
# Training Accuracy (Overall): 35% (6377/18144)
# Epoch number 5
#  Current loss 1.653686285018921
#
#
# Training Accuracy of     0: 17% (675/3777)
#
# Training Accuracy of     1:  0% ( 0/413)
#
# Training Accuracy of     2:  4% (165/3858)
#
# Training Accuracy of     3: 73% (5025/6804)
#
# Training Accuracy of     4: 31% (1469/4691)
#
# Training Accuracy of     5: 34% (1586/4549)
#
# Training Accuracy of     6: 19% (595/3012)
#
# Training Accuracy (Overall): 35% (9515/27104)
# Epoch number 5
#  Current loss 1.6233805418014526
#
#
# Validation Accuracy of     0: 28% ( 2/ 7)
#
# Validation Accuracy of     1:  0% ( 0/ 1)
#
# Validation Accuracy of     2:  0% ( 0/ 9)
#
# Validation Accuracy of     3: 77% (14/18)
#
# Validation Accuracy of     4: 36% ( 4/11)
#
# Validation Accuracy of     5: 42% ( 6/14)
#
# Validation Accuracy of     6:  0% ( 0/ 4)
#
# Validation Accuracy (Overall): 40% (26/64)
# Epoch number 5
#  Current loss 1.7762022018432617
#
#
# Validation Accuracy of     0: 15% (65/426)
#
# Validation Accuracy of     1:  0% ( 0/55)
#
# Validation Accuracy of     2:  5% (23/443)
#
# Validation Accuracy of     3: 71% (580/811)
#
# Validation Accuracy of     4: 25% (143/559)
#
# Validation Accuracy of     5: 40% (243/595)
#
# Validation Accuracy of     6: 17% (66/375)
#
# Validation Accuracy (Overall): 34% (1120/3264)
# Validation loss for epoch 5: 1.667941
# Epoch number 6
#  Current loss 1.679482340812683
#
#
# Training Accuracy of     0:  9% ( 3/32)
#
# Training Accuracy of     1:  0% ( 0/ 2)
#
# Training Accuracy of     2:  3% ( 1/31)
#
# Training Accuracy of     3: 71% (32/45)
#
# Training Accuracy of     4: 27% (15/54)
#
# Training Accuracy of     5: 48% (16/33)
#
# Training Accuracy of     6: 11% ( 3/27)
#
# Training Accuracy (Overall): 31% (70/224)
# Epoch number 6
#  Current loss 1.6870651245117188
#
#
# Training Accuracy of     0: 16% (207/1256)
#
# Training Accuracy of     1:  0% ( 0/150)
#
# Training Accuracy of     2:  5% (77/1316)
#
# Training Accuracy of     3: 73% (1673/2273)
#
# Training Accuracy of     4: 30% (492/1612)
#
# Training Accuracy of     5: 32% (505/1545)
#
# Training Accuracy of     6: 20% (215/1032)
#
# Training Accuracy (Overall): 34% (3169/9184)
# Epoch number 6
#  Current loss 1.6370733976364136
#
#
# Training Accuracy of     0: 19% (497/2551)
#
# Training Accuracy of     1:  0% ( 0/266)
#
# Training Accuracy of     2:  5% (147/2597)
#
# Training Accuracy of     3: 73% (3347/4526)
#
# Training Accuracy of     4: 29% (939/3154)
#
# Training Accuracy of     5: 34% (1067/3054)
#
# Training Accuracy of     6: 18% (378/1996)
#
# Training Accuracy (Overall): 35% (6375/18144)
# Epoch number 6
#  Current loss 1.6736266613006592
#
#
# Training Accuracy of     0: 18% (682/3781)
#
# Training Accuracy of     1:  0% ( 0/412)
#
# Training Accuracy of     2:  4% (192/3873)
#
# Training Accuracy of     3: 73% (5009/6780)
#
# Training Accuracy of     4: 29% (1388/4687)
#
# Training Accuracy of     5: 35% (1629/4579)
#
# Training Accuracy of     6: 19% (569/2992)
#
# Training Accuracy (Overall): 34% (9469/27104)
# Epoch number 6
#  Current loss 1.8054232597351074
#
#
# Validation Accuracy of     0:  7% ( 1/14)
#
# Validation Accuracy of     1:  0% ( 0/ 2)
#
# Validation Accuracy of     2: 12% ( 1/ 8)
#
# Validation Accuracy of     3: 77% ( 7/ 9)
#
# Validation Accuracy of     4: 23% ( 3/13)
#
# Validation Accuracy of     5: 30% ( 3/10)
#
# Validation Accuracy of     6: 25% ( 2/ 8)
#
# Validation Accuracy (Overall): 26% (17/64)
# Epoch number 6
#  Current loss 1.6042848825454712
#
#
# Validation Accuracy of     0: 10% (46/424)
#
# Validation Accuracy of     1:  0% ( 0/51)
#
# Validation Accuracy of     2:  7% (35/449)
#
# Validation Accuracy of     3: 77% (635/820)
#
# Validation Accuracy of     4: 32% (178/549)
#
# Validation Accuracy of     5: 23% (139/592)
#
# Validation Accuracy of     6: 17% (65/379)
#
# Validation Accuracy (Overall): 33% (1098/3264)
# Validation loss for epoch 6: 1.670798
# Epoch number 7
#  Current loss 1.6338987350463867
#
#
# Training Accuracy of     0: 25% ( 8/32)
#
# Training Accuracy of     1:  0% ( 0/ 3)
#
# Training Accuracy of     2: 13% ( 4/30)
#
# Training Accuracy of     3: 88% (52/59)
#
# Training Accuracy of     4: 31% (13/41)
#
# Training Accuracy of     5: 33% (10/30)
#
# Training Accuracy of     6: 10% ( 3/29)
#
# Training Accuracy (Overall): 40% (90/224)
# Epoch number 7
#  Current loss 1.6202033758163452
#
#
# Training Accuracy of     0: 18% (232/1253)
#
# Training Accuracy of     1:  0% ( 0/127)
#
# Training Accuracy of     2:  5% (73/1340)
#
# Training Accuracy of     3: 74% (1695/2271)
#
# Training Accuracy of     4: 34% (538/1581)
#
# Training Accuracy of     5: 35% (556/1577)
#
# Training Accuracy of     6: 17% (185/1035)
#
# Training Accuracy (Overall): 35% (3279/9184)
# Epoch number 7
#  Current loss 1.6406772136688232
#
#
# Training Accuracy of     0: 17% (441/2504)
#
# Training Accuracy of     1:  0% ( 0/264)
#
# Training Accuracy of     2:  6% (175/2630)
#
# Training Accuracy of     3: 74% (3350/4509)
#
# Training Accuracy of     4: 31% (1001/3133)
#
# Training Accuracy of     5: 34% (1047/3079)
#
# Training Accuracy of     6: 18% (367/2025)
#
# Training Accuracy (Overall): 35% (6381/18144)
# Epoch number 7
#  Current loss 1.6974717378616333
#
#
# Training Accuracy of     0: 18% (711/3780)
#
# Training Accuracy of     1:  0% ( 0/415)
#
# Training Accuracy of     2:  5% (204/3856)
#
# Training Accuracy of     3: 74% (5122/6837)
#
# Training Accuracy of     4: 31% (1490/4684)
#
# Training Accuracy of     5: 33% (1522/4529)
#
# Training Accuracy of     6: 18% (566/3003)
#
# Training Accuracy (Overall): 35% (9615/27104)
# Epoch number 7
#  Current loss 1.6559967994689941
#
#
# Validation Accuracy of     0:  0% ( 0/ 9)
#
# Validation Accuracy of     1:  0% ( 0/ 0)
#
# Validation Accuracy of     2:  0% ( 0/ 8)
#
# Validation Accuracy of     3: 61% (11/18)
#
# Validation Accuracy of     4: 22% ( 2/ 9)
#
# Validation Accuracy of     5: 28% ( 4/14)
#
# Validation Accuracy of     6: 16% ( 1/ 6)
#
# Validation Accuracy (Overall): 28% (18/64)
# Epoch number 7
#  Current loss 1.5658504962921143
#
#
# Validation Accuracy of     0: 12% (53/429)
#
# Validation Accuracy of     1:  0% ( 0/50)
#
# Validation Accuracy of     2:  6% (28/448)
#
# Validation Accuracy of     3: 70% (567/810)
#
# Validation Accuracy of     4: 27% (151/547)
#
# Validation Accuracy of     5: 36% (216/592)
#
# Validation Accuracy of     6: 25% (99/388)
#
# Validation Accuracy (Overall): 34% (1114/3264)
# Validation loss for epoch 7: 1.668220
# Epoch number 8
#  Current loss 1.6659717559814453
#
#
# Training Accuracy of     0:  9% ( 2/22)
#
# Training Accuracy of     1:  0% ( 0/ 4)
#
# Training Accuracy of     2: 15% ( 6/40)
#
# Training Accuracy of     3: 74% (35/47)
#
# Training Accuracy of     4: 25% (10/39)
#
# Training Accuracy of     5: 44% (21/47)
#
# Training Accuracy of     6: 20% ( 5/25)
#
# Training Accuracy (Overall): 35% (79/224)
# Epoch number 8
#  Current loss 1.650656819343567
#
#
# Training Accuracy of     0: 17% (212/1235)
#
# Training Accuracy of     1:  0% ( 0/142)
#
# Training Accuracy of     2:  6% (91/1356)
#
# Training Accuracy of     3: 72% (1677/2302)
#
# Training Accuracy of     4: 32% (532/1619)
#
# Training Accuracy of     5: 36% (553/1510)
#
# Training Accuracy of     6: 19% (198/1020)
#
# Training Accuracy (Overall): 35% (3263/9184)
# Epoch number 8
#  Current loss 1.7275292873382568
#
#
# Training Accuracy of     0: 17% (426/2483)
#
# Training Accuracy of     1:  0% ( 0/272)
#
# Training Accuracy of     2:  5% (148/2636)
#
# Training Accuracy of     3: 73% (3320/4546)
#
# Training Accuracy of     4: 30% (949/3141)
#
# Training Accuracy of     5: 38% (1170/3055)
#
# Training Accuracy of     6: 17% (359/2011)
#
# Training Accuracy (Overall): 35% (6372/18144)

# %%
print('\n Loss History')
plt.plot(train_counter,train_loss_history, label="train")
plt.plot(valid_counter,valid_loss_history, label="valid")
plt.legend()
plt.show()


print('\n Accuracy History')
plt.plot(train_counter,train_accuracy_history, label="train")
plt.plot(valid_counter,valid_accuracy_history, label="valid")
plt.legend()
plt.show()
# Out:
#  Loss History
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78d837caf310> in <module>()
#       1 print('\n Loss History')
# ----> 2 plt.plot(train_counter,train_loss_history, label="train")
#       3 plt.plot(valid_counter,valid_loss_history, label="valid")
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
net.eval()
model1.eval()

train_counter = []
train_iteration_number= 0

valid_counter = []
valid_iteration_number= 0

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

train_class_correct = list(0 for i in range(num_classes))
train_class_total = list(0 for i in range(num_classes))

valid_class_correct = list(0 for i in range(num_classes))
valid_class_total = list(0 for i in range(num_classes))


for i, data in enumerate(train_loader,0):
        
  img1 , label = data
        #img1, label = Variable(img1), Variable(label)
  img1 , label = img1.cuda(), label.cuda()
        #img1, label = Variable(img1), Variable(label)
        #row, img0, img1 , label = row.cuda(), img0.cuda(), img1.cuda() , label.cuda()
  

  output1= model1(img1)      
  output = net(output1)
  _, pred= torch.max(output,1)
        
        #plt.imshow(img1.data[0])

        #a = plt.imshow(img1.data[0].permute(1, 2, 0))
        #plt.title(train_loader.dataset.classes[pred[0]])
        #a.set_title = train_loader.dataset.classes[pred[0]]
        #plt.show()
  correct = pred.eq(label.view_as(pred))
  for j in range(len(label)):
    target = label[j].data
    train_class_correct[target] += correct[j].item()
    train_class_total[target] += 1

for i in range(num_classes):
    if train_class_total[i] > 0:
        print('\nTraining Accuracy of %5s: %2d%% (%2d/%2d)' % (str(i), 100 * train_class_correct[i] / train_class_total[i],
                                                               np.sum(train_class_correct[i]), np.sum(train_class_total[i])))

print('\nTraining Accuracy (Overall): %2d%% (%2d/%2d)' % (100. * np.sum(train_class_correct) / np.sum(train_class_total),
                                                                  np.sum(train_class_correct), np.sum(train_class_total)))
    
for i, data in enumerate(test_loader,0):
     
  img1 , label = data
  img1 , label = img1.cuda(), label.cuda()
        #row, img0, img1 , label = row.cuda(), img0.cuda(), img1.cuda() , label.cuda()
        
  output1= model1(img1)
  output = net(output1)
        #combined = torch.cat([vgg,res1,sen1],1)
        #output= net(combined)
  _, pred= output.max(1)
        
        
       
  correct = pred.eq(label.view_as(pred))
  for j in range(len(label)):
    target = label[j].data
    valid_class_correct[target] += correct[j].item()
    valid_class_total[target] += 1
                       

for i in range(num_classes):
    if train_class_total[i] > 0:
          print('\nValdiation Accuracy of %5s: %2d%% (%2d/%2d)' % (str(i), 100 * valid_class_correct[i] / valid_class_total[i],
                                                                   np.sum(valid_class_correct[i]), np.sum(valid_class_total[i])))

print('\nValidation Accuracy (Overall): %2d%% (%2d/%2d)' % (100. * np.sum(valid_class_correct) / np.sum(valid_class_total),
                                                                      np.sum(valid_class_correct), np.sum(valid_class_total)))
